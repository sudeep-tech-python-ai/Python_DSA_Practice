# %%
# Question : Insert at Tail - Recursive
# Title: Implement insert_at_tail_recursive for a Linked List

# Description: In this exercise, you'll implement the insert_at_tail_recursive function for a singly linked list. The Node structure is provided. Your task is to complete the insert_at_tail_recursive function.

# The insert_at_tail_recursive function should add a new node with the given data at the end of the linked list using a recursive approach. If the list is empty, the new node should become the head of the list.

# Parameters:

# head: The head of the linked list (can be None for an empty list)

# data: The data to be inserted at the tail

# Return:

# The head of the modified linked list

# Examples:

# If the list is empty and you insert 5, the list should become: 5 -> None

# If the list is 1 -> 2 and you insert 3, the list should become: 1 -> 2 -> 3 -> None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def insert_at_tail_recursive(head, data):
    # TODO: Implement this function
    tail=head
    if tail==None:
        return  Node(data)
    else:
        head.next=insert_at_tail_recursive(tail.next,data)
        return head

# %%
# Insert at Tail - Recursive
# Problem Description: Insert at Tail (Recursively)

# Problem Statement:
# You are given a linked list, and your task is to write a function that inserts a new node at the end (tail) of the linked list recursively.

# Function Signature:

# def insert_at_tail(self, head: Node, data: int) -> Node:
#     pass
# head: The head node of the linked list.

# data: The value of the new node that needs to be inserted at the tail of the list.

# Expected Behavior:

# If the list is empty (i.e., head is None), insert the node as the head.

# Otherwise, recursively traverse the list and insert the new node at the tail.

# Constraints:

# The function should not use loops.

# The function should update the list by inserting the new node at the tail and return the head node.

# Examples:

# Example 1:

# [1, 2, 3]
# data = 4
# Output:

# [1, 2, 3, 4]
# Example 2:

# []
# data = 5
# Output:

# [5]
# Example 3:

# [10]
# data = 15
# Output:

# [10, 15]

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_tail(self, head: Node, data: int) -> Node:
        # Complete this recursive function
        self.head=head
        tail=self.head
        if tail==None:
            return Node(data)
        else:
            tail.next=self.insert_at_tail(tail.next,data)
            return head
